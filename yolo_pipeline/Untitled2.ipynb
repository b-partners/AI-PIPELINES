# %%
# !cd revetements-new-dataset/ ; unzip dataset_revets_new.zip
# Out:
# Archive:  dataset_revets_new.zip
#    creating: train/
#    creating: train/images/
#   inflating: train/images/1083698_735521.jpg
#   inflating: train/images/1062734_721812.jpg
#   inflating: train/images/1065550_705298.jpg
#   inflating: train/images/1089441_766103.jpg
#   inflating: train/images/1037326_740226.jpg
#   inflating: train/images/1075414_765141.jpg
#   inflating: train/images/1077875_734590.jpg
#   inflating: train/images/1078281_734985.jpg
#   inflating: train/images/1056823_766181.jpg
#   inflating: train/images/1083664_735574.jpg
#   inflating: train/images/1076626_748416.jpg
#   inflating: train/images/1065543_705298.jpg
#   inflating: train/images/1060203_759625.jpg
#   inflating: train/images/1050194_718900.jpg
#   inflating: train/images/1060201_759631.jpg
#   inflating: train/images/1077143_755073.jpg
#   inflating: train/images/1062445_701723.jpg
#   inflating: train/images/1060944_716543.jpg
#   inflating: train/images/1065549_705289.jpg
# ...

# %%
import glob, cv2

for img_fp in glob.glob("revetements-new-dataset/train/images/*.jpg") + glob.glob("revetements-new-dataset/val/images/*.jpg"):
    img = cv2.imread(img_fp)
    if img.shape[0] == 1024:
        print(img_fp)
        n_img = cv2.resize(img, (512, 512))
        cv2.imwrite(img_fp, n_img)
# Out:
# revetements-new-dataset/train/images/1083698_735521.jpg
# revetements-new-dataset/train/images/1062734_721812.jpg
# revetements-new-dataset/train/images/1089441_766103.jpg
# revetements-new-dataset/train/images/1037326_740226.jpg
# revetements-new-dataset/train/images/1075414_765141.jpg
# revetements-new-dataset/train/images/1077875_734590.jpg
# revetements-new-dataset/train/images/1083664_735574.jpg
# revetements-new-dataset/train/images/1077143_755073.jpg
# revetements-new-dataset/train/images/1062445_701723.jpg
# revetements-new-dataset/train/images/1039210_714494.jpg
# revetements-new-dataset/train/images/1083240_735734.jpg
# revetements-new-dataset/train/images/1073854_720687.jpg
# revetements-new-dataset/train/images/1077104_755028.jpg
# revetements-new-dataset/train/images/1039040_714564.jpg
# revetements-new-dataset/train/images/1037817_728332.jpg
# revetements-new-dataset/train/images/1051654_739176.jpg
# revetements-new-dataset/train/images/1063492_722900.jpg
# ...
