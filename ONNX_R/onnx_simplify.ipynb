# %%
from onnxsim import simplify
import onnx

# Load your ONNX model
model = onnx.load("model_quant.onnx")

# Simplify
model_simplified, check = simplify(model)

assert check, "Simplified ONNX model could not be validated"

# Save it
onnx.save(model_simplified, "model_quant_simplified.onnx")

# %%
!

# %%
from onnxruntime.quantization import quantize_dynamic, QuantType

quantize_dynamic(
    model_input="model_preprocessed.onnx",
    model_output="model_quant4.onnx",
    weight_type=QuantType.QInt4 # or QuantType.QUInt8
)

# %%
from onnxconverter_common import float16

import onnx
model = onnx.load("model_preprocessed.onnx")
model_fp16 = float16.convert_float_to_float16(model)
onnx.save(model_fp16, "model_fp16.onnx")
# Out:
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.513783432120847e-20 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.746591609529898e-20 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.3987433201645124e-20 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.278304694952124e-20 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.16674571618114e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.6728847640479216e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.7561419521838016e-24 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.9171140293409384e-24 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.5391154310570504e-23 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.7874299106387346e-24 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.266773932064098e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.1602813699294074e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.262274533317623e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.902885401333654e-12 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.9278354914119564e-12 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.5765503486031562e-11 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.3825654163190926e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.745630708517638e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.911551272826273e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.944237268020515e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.226318316334082e-25 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.027783221116153e-26 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.895566480709209e-25 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.055420554069059e-25 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 7.479717681112531e-21 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.428583961738447e-20 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.2901176401611525e-20 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.5258722878778672e-19 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.6570513332196774e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.715098450507864e-17 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.4442799360029834e-19 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.520535165778371e-19 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.21478466033942e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.76698535748242e-18 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.213221688724843e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.275017235182531e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.876207868839313e-21 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.4851197951808034e-23 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.7572089394804895e-21 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.824064762358451e-21 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.2630446849802865e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.2909896202349955e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.6220383154899332e-18 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.260841812467348e-18 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.936460706321699e-20 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.3094774458142562e-20 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.5251264817386757e-24 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.6568160021108396e-24 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.5953807991641042e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.960341832254244e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.648021565989228e-20 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.161461942606269e-20 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.1582063697263535e-23 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.477524090002661e-24 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.781364365020636e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.5214290355187503e-19 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.776703339697718e-19 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.9858413661607885e-23 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.3659507199288589e-24 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.064621615892752e-21 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.31270039789806e-21 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.9535891264944248e-20 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.3463749027474271e-20 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.761780044907702e-15 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.740556159361575e-15 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.466380079174806e-15 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.230961116257528e-14 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.939320713516007e-16 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.0831110917978162e-15 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.484536806463439e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.464664028423158e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.563983241861024e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.631609465417193e-21 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.012743100390553e-23 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.9075475588972557e-21 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.6354309550269744e-21 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.880660086552493e-21 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.089300612359961e-21 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.047064251563325e-20 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.1666433873068086e-20 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.998149024707025e-20 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.238901185415412e-21 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.000429555770751e-20 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.9133141548336154e-20 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.4303389583858461e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.1630147955798975e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.907944606280523e-10 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.64159445228014e-15 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.149932593487098e-16 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.49390088977475e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.3410279831038707e-10 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.190051943770868e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.7812493702251686e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.6289735116359338e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.0088260227192336e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.6270974728959118e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.882918305947896e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 7.52755369148872e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.810286670040796e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.172943863205546e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.4467263649039523e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.7574600380830816e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.4947374893381493e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.53214316181527e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.751012692265192e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.960792582802242e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.8723028460954083e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.375078521690057e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.96861615687061e-10 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.280795865151958e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.3981749980018776e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.743025445146486e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.2333326582236737e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.1521364246268604e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.804659343131789e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.1698635777056552e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.187893740796426e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.429003969657174e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.9372136722827236e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.5072355807888016e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/adelb/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.963362070815492e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))

# %%
model = onnx.load("model_fp16.onnx")
node_types = set(node.op_type for node in model.graph.node)
print("Ops used in model:", node_types)
# Out:
# Ops used in model: {'MaxPool', 'Shape', 'Slice', 'Sigmoid', 'GlobalAveragePool', 'Resize', 'Relu', 'Add', 'Mul', 'Unsqueeze', 'Gather', 'Div', 'Sub', 'Concat', 'Conv', 'Cast'}

# %%
import os
import cv2
import numpy as np
from onnxruntime.quantization import quantize_static, CalibrationDataReader, QuantType

# Calibration DataReader
class ImageFolderReader(CalibrationDataReader):
    def __init__(self, folder, input_name, size=(224, 224)):
        self.data = []
        self.input_name = input_name
        for fname in os.listdir(folder):
            path = os.path.join(folder, fname)
            img = cv2.imread(path)
            if img is None:
                continue
            img = img.transpose(2, 0, 1)  # HWC -> CHW
            self.data.append({input_name: np.expand_dims(img, axis=0)})
        self.iterator = iter(self.data)

    def get_next(self):
        return next(self.iterator, None)

# Paths
input_model = "model_preprocessed.onnx"
output_model = "model_quantized.onnx"
calibration_folder = "../DATA/dataset/test/images"  # Path to your calibration image folder

# Get input name from the model
import onnxruntime as ort
session = ort.InferenceSession(input_model)
input_name = session.get_inputs()[0].name  # Get the input name

# Quantize the model
quantize_static(
    model_input=input_model,
    model_output=output_model,
    calibration_data_reader=ImageFolderReader(calibration_folder, input_name),
    quant_format=QuantType.QUInt8,  # QDQ (Quantize-Dequantize) format for best compatibility
    weight_type=QuantType.QUInt8,  # Quantize weights to int8
    activation_type=QuantType.QUInt8,  # Quantize activations to int8
    
)

print(f"Quantized model saved to: {output_model}")
# Out:
# Quantized model saved to: model_quantized.onnx

# %%
import numpy as np
import onnxruntime as ort
onnx_orig= "/home/adelb/Downloads/comp_200eps_abloss_model3b_3c_se_resnext50_32x4d_512.onnx"
onnx_simp= 'model_quantized.onnx'


sample = np.random.randint(0, 256, (2, 3, 1024, 1024), dtype= np.uint8)

orig_session = ort.InferenceSession(
    onnx_orig, providers=["CPUExecutionProvider"]
)

simp_session= ort.InferenceSession(
    onnx_simp, providers=["CPUExecutionProvider"]
)

# compute ONNX Runtime output prediction
ort_inputs = {"input": sample}
orig_outputs = orig_session.run(output_names=None, input_feed=ort_inputs)

simp_outputs = simp_session.run(output_names=None, input_feed=ort_inputs)



# compare ONNX Runtime and PyTorch results
d= np.testing.assert_allclose(simp_outputs[0], orig_outputs[0], rtol=1e-2, atol=1e-3)

print("Exported model has been tested with ONNXRuntime, and the result looks good!")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 26
#      21 simp_outputs = simp_session.run(output_names=None, input_feed=ort_inputs)
#      25 # compare ONNX Runtime and PyTorch results
# ---> 26 d= np.testing.assert_allclose(simp_outputs[0], orig_outputs[0], rtol=1e-2, atol=1e-3)
#      28 print("Exported model has been tested with ONNXRuntime, and the result looks good!")
#
#     [... skipping hidden 1 frame]
#
# File /usr/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/Documents/Bpartners/image_analysis/roof/lib/python3.10/site-packages/numpy/testing/_private/utils.py:797, in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf, strict)
#     793         err_msg += '\n' + '\n'.join(remarks)
#     794         msg = build_err_msg([ox, oy], err_msg,
#     795                             verbose=verbose, header=header,
#     796                             names=('x', 'y'), precision=precision)
# --> 797         raise AssertionError(msg)
#     798 except ValueError:
#     799     import traceback
#
# AssertionError:
# Not equal to tolerance rtol=0.01, atol=0.001
#
# Mismatched elements: 8688498 / 9437184 (92.1%)
# Max absolute difference: 4.8479233
# Max relative difference: 7497466.5
#  x: array([[[[  3.016465,   3.016465,   3.016465, ...,   2.681303,
#             2.34614 ,   2.34614 ],
#          [  3.016465,   3.351628,   3.686791, ...,   2.681303,...
#  y: array([[[[  2.266474,   2.399349,   2.532224, ...,   2.688377,
#             2.538295,   2.388207],
#          [  2.324796,   2.547629,   2.770462, ...,   2.554197,...
